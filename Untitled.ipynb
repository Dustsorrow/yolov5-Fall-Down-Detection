# %%
# !python detect.py --weight best.pt --img 640 --conf 0.25
# Out:
# detect: weights=['best.pt'], source=test, data=data\VOC.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=out, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  2022-6-3 torch 1.11.0 CUDA:0 (NVIDIA GeForce GTX 1660 Ti, 6144MiB)
#
# Fusing layers...
# Model summary: 224 layers, 7059304 parameters, 0 gradients
# video 1/3 (1/216) C:\Users\14982\yolov5-master\test\video (59).avi: 480x640 Done. (0.023s)
# video 1/3 (2/216) C:\Users\14982\yolov5-master\test\video (59).avi: 480x640 Done. (0.014s)
# video 1/3 (3/216) C:\Users\14982\yolov5-master\test\video (59).avi: 480x640 Done. (0.014s)
# video 1/3 (4/216) C:\Users\14982\yolov5-master\test\video (59).avi: 480x640 Done. (0.014s)
# ...
